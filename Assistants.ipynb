# %% [markdown]
# # Генеративний AI: Огляд та Концепти
#
# Цей документ є навчальним матеріалом і охоплює базові та прикладні аспекти роботи з Generative AI, включно з оглядом основних моделей (Claude, ChatGPT, Gemini), концепціями токенізації та можливостями створення кастомних чатботів.
#
# ## 1. Огляд великих мовних моделей (Claude, ChatGPT, Gemini)
#
# ### 1.1 Відео-огляд 1
# - **Посилання:** [Claude, ChatGPT, Gemini - Загальний огляд](https://www.youtube.com/watch?v=YgvL0dA_2Pg)
# - **Опис:** Відео знайомить з основними можливостями та відмінностями між популярними LLM — Claude (Anthropic), ChatGPT (OpenAI) та Gemini (Google).
#
# ### 1.2 Відео-огляд 2
# - **Посилання:** [Claude, ChatGPT, Gemini - Другий огляд](https://www.youtube.com/watch?v=7vrfs8507E4)
# - **Опис:** Додатковий огляд функціоналу, сильних і слабких сторін моделей.
#
# ## 2. Порівняння моделей
#
# ### 2.1 Порівняльна таблиця 1
# - **Посилання:** [Порівняння моделей](http://bit.ly/3HKrXKS)
# - **Опис:** Таблиця із характеристиками моделей Claude, ChatGPT і Gemini за параметрами — якість, швидкість, ціна, доступність API тощо.
#
# ### 2.2 Порівняльна таблиця 2
# - **Посилання:** [Додаткове порівняння моделей](http://bit.ly/3STkQlH)
# - **Опис:** Інше джерело з оновленим або альтернативним порівнянням.
#
# ## 3. Концепція токенізації в мовних моделях
#
# ### 3.1 Навчальний модуль від Microsoft
# - **Посилання:** [Microsoft Learn - Tokenization](https://learn.microsoft.com/en-us/training/modules/fundamentals-generative-ai/3-language-models)
# - **Опис:** Пояснення, як мовні моделі розбивають текст на токени, як це впливає на якість відповідей та обмеження.
#
# ### 3.2 Додатковий ресурс
# - **Посилання:** [Tokenization](https://bit.ly/4mKKKWl)
# - **Опис:** Поглиблений розбір процесу токенізації з прикладами та візуалізаціями.
#
# ## 4. Кастомізація ChatGPT (налаштування під бізнес)
#
# ### 4.1 Загальний огляд кастомізації
# - **Посилання:** [Custom ChatGPT - General overview](https://www.youtube.com/watch?v=Tp_TX4UWZf4)
# - **Опис:** Як створювати спеціалізовані версії ChatGPT для вирішення конкретних задач бізнесу.
#
# ### 4.2 Перспектива бізнес-аналітика
# - **Посилання:** [Custom ChatGPT from BA perspective](https://softserve.csod.com/LMS/Video/LaunchVideo.aspx?loid=3277e099-3eb9-4a11-98e6-f54ab3ca071b)
# - **Опис:** Як бізнес-аналітик може використовувати кастомізовані AI-рішення для оптимізації бізнес-процесів.
#
# ### 4.3 Порівняння кастомного ChatGPT і реальних проектів
# - **Посилання:** [Custom ChatGPT vs Projects](https://www.youtube.com/watch?v=2KGpQcCQZhY)
# - **Опис:** Порівняння можливостей кастомного ChatGPT з типовими IT-проектами. Обговорення кейсів, обмежень та потенціалу.
#
# ---
#
# > 📌 Цей документ є вступом до роботи з Generative AI і підходить як для початківців, так і для фахівців, які хочуть розширити своє розуміння застосування мовних моделей у бізнесі.
