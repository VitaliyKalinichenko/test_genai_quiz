# %% [markdown]
# # Communicative Assistants
#
# This document is an educational material covering fundamental aspects of working with communicative assistants, including an overview of major models (Claude, ChatGPT, Gemini), tokenization concepts, and capabilities for building custom GPTs.
#
# ## 1. Overview of Large Language Models (Claude, ChatGPT, Gemini)
#
# ### 1.1 Video Overview 1
# - **Link:** [Claude, ChatGPT, Gemini - General Overview](https://www.youtube.com/watch?v=YgvL0dA_2Pg)
# - **Description:** This video introduces the key features and differences between the most popular LLMs — Claude (Anthropic), ChatGPT (OpenAI), and Gemini (Google).
#
# ### 1.2 Video Overview 2
# - **Link:** [Claude, ChatGPT, Gemini - Second Overview](https://www.youtube.com/watch?v=7vrfs8507E4)
# - **Description:** An additional review highlighting functionality, strengths, and weaknesses of each model.
#
# ## 2. Model Comparison
#
# ### 2.1 Comparison Table 1
# - **Link:** [Model Comparison](http://bit.ly/3HKrXKS)
# - **Description:** A table comparing Claude, ChatGPT, and Gemini in terms of quality, speed, pricing, API availability, and more.
#
# ### 2.2 Comparison Table 2
# - **Link:** [Additional Model Comparison](http://bit.ly/3STkQlH)
# - **Description:** An alternative source with updated or complementary comparison data.
#
# ## 3. Tokenization Concept in Language Models
#
# ### 3.1 Learning Module by Microsoft
# - **Link:** [Microsoft Learn - Tokenization](https://learn.microsoft.com/en-us/training/modules/fundamentals-generative-ai/3-language-models)
# - **Description:** Explains how language models split text into tokens and how this affects response quality, limits, and cost.
#
# ### 3.2 Additional Resource
# - **Link:** [Tokenization](https://bit.ly/4mKKKWl)
# - **Description:** A deeper dive into tokenization with examples and visual explanations.
#
# ## 4. Customizing ChatGPT
#
# ### 4.1 General Overview of Customization
# - **Link:** [Custom ChatGPT - General Overview](https://www.youtube.com/watch?v=Tp_TX4UWZf4)
# - **Description:** How to create specialized versions of ChatGPT to solve specific business tasks.
#
# ### 4.2 Business Analyst Perspective (as an example for software testing direction)
# - **Link:** [Custom ChatGPT from BA Perspective](https://softserve.csod.com/LMS/Video/LaunchVideo.aspx?loid=3277e099-3eb9-4a11-98e6-f54ab3ca071b)
# - **Description:** How a business analyst can leverage customized AI solutions to optimize business processes.
#
# ### 4.3 Custom ChatGPT vs IT Projects (general overview)
# - **Link:** [Custom ChatGPT vs Projects](https://www.youtube.com/watch?v=2KGpQcCQZhY)
# - **Description:** Comparison of custom ChatGPT capabilities versus typical IT projects. Discussion of use cases, limitations, and potential.
#
# ---
#
# > .
