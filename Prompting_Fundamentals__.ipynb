# %% [markdown]
# # Prompting Fundamentals: Key Resources and Learning Materials
#
# This document provides a structured collection of resources to help you master prompt engineering — the art of interacting effectively with Large Language Models (LLMs) such as ChatGPT, Claude, and Gemini. It covers both fundamental and advanced concepts, along with practical materials.
#
# ## 1. Video Tutorials on Prompt Engineering
#
# ### 1.1 Prompt Engineering Tutorial – Master ChatGPT and LLM Responses
# - **Link:** [Watch on YouTube](https://www.youtube.com/watch?v=_ZvnD73m40o)
# - **Description:** A comprehensive tutorial designed to teach effective prompting techniques, including practical examples.
# - **Note:** *Part of Curriculum*
#
# ### 1.2 Introduction to Prompt Engineering by OpenAI
# - **Link:** [Watch on OpenAI Academy](https://academy.openai.com/public/videos/introduction-to-prompt-engineering-2025-02-13)
# - **Description:** An official OpenAI introduction to the basics of prompt engineering, with foundational concepts and examples.
# - **Note:** *Part of Curriculum*
#
# ### 1.3 Advanced Prompt Engineering by OpenAI
# - **Link:** [Watch on OpenAI Academy](https://academy.openai.com/home/videos/advanced-prompt-engineering-2025-02-13)
# - **Description:** A follow-up video exploring advanced techniques and strategies for complex prompting scenarios.
# - **Note:** *Part of Curriculum*
#
# ## 2. Documentation and Handbooks
#
# ### 2.1 Prompting Handbook
# - **Link:** [Access Handbook](http://bit.ly/4n5CKPJ)
# - **Description:** Detailed guide covering techniques and frameworks. Focus on Sections 5, 6, and 7 for in-depth knowledge about prompting strategies and frameworks.
#
# ## 3. Practical Exercises and Examples
#
# ### 3.1 Prompt Examples (Basic)
# - **Link:** [View on GitHub](https://github.com/VitaliyKalinichenko/test_genai_quiz/blob/main/Prompt.ipynb)
# - **Description:** Notebook containing basic prompt examples to practice and understand prompt structures.
#
# ### 3.2 Frameworks (Basic)
# - **Link:** [View on GitHub](https://github.com/VitaliyKalinichenko/test_genai_quiz/blob/main/Framework.ipynb)
# - **Description:** Notebook focusing on applying different prompting frameworks with examples.
#
# ## 4. Additional Research and Libraries
#
# ### 4.1 Deep Research and Models
# - **Link:** [Visit Prompting Guide](https://www.promptingguide.ai)
# - **Description:** A comprehensive resource for deep research in prompt engineering, including reasoning strategies, model selection, and fine-tuning.
# - **Note:** *Optional*
#
# ### 4.2 Prompt Library by Anthropic
# - **Link:** [Visit Prompt Library](https://docs.anthropic.com/en/resources/prompt-library/library)
# - **Description:** A collection of well-crafted prompts designed for various use cases. Helpful for inspiration and learning.
# - **Note:** *Optional*
#
# ---
#
# > 📌 This guide is a core part of the learning curriculum on Generative AI and prompt engineering. It is suitable for both beginners and experienced users looking to refine their skills.
